# %% [markdown]
# # API Trading Using CCXT

# %%
import ccxt
import pandas as pd

# %%
print(ccxt.exchanges)
# Out:
# ['alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitforex', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitstamp1', 'bittrex', 'bitvavo', 'bkex', 'bl3p', 'blockchaincom', 'btcalpha', 'btcbox', 'btcex', 'btcmarkets', 'btctradeua', 'btcturk', 'buda', 'bybit', 'cex', 'coinbase', 'coinbaseprime', 'coinbasepro', 'coincheck', 'coinex', 'coinfalcon', 'coinmate', 'coinone', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'flowbtc', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'huobi', 'huobijp', 'huobipro', 'idex', 'independentreserve', 'indodax', 'itbit', 'kraken', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'lbank2', 'luno', 'lykke', 'mercado', 'mexc', 'mexc3', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okex', 'okex5', 'okx', 'paymi
# ...

# %%
binance = ccxt.binanceus()
binance
# Out:
# ccxt.binanceus()

# %%
binance.fetchTicker(symbol='BTC/USD')
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1673491493491,
#  'datetime': '2023-01-12T02:44:53.491Z',
#  'high': 18286.07,
#  'low': 17312.68,
#  'bid': 18259.89,
#  'bidVolume': 0.261093,
#  'ask': 18262.15,
#  'askVolume': 0.05,
#  'vwap': 17714.0038,
#  'open': 17415.18,
#  'close': 18262.16,
#  'last': 18262.16,
#  'previousClose': 17415.62,
#  'change': 846.98,
#  'percentage': 4.863,
#  'average': 17838.67,
#  'baseVolume': 10512.173717,
#  'quoteVolume': 186212685.1199,
#  'info': {'symbol': 'BTCUSD',
#   'priceChange': '846.9800',
#   'priceChangePercent': '4.863',
#   'weightedAvgPrice': '17714.0038',
#   'prevClosePrice': '17415.6200',
#   'lastPrice': '18262.1600',
#   'lastQty': '0.04596900',
#   'bidPrice': '18259.8900',
#   'bidQty': '0.26109300',
#   'askPrice': '18262.1500',
#   'askQty': '0.05000000',
#   'openPrice': '17415.1800',
#   'highPrice': '18286.0700',
#   'lowPrice': '17312.6800',
#   'volume': '10512.17371700',
#   'quoteVolume': '186212685.1199',
# ...

# %%
binanceusdm = ccxt.binanceusdm()
binanceusdm
# Out:
# ccxt.binanceusdm()

# %%
binance.fetchTicker(symbol='BTC/USDT')
# Out:
# {'symbol': 'BTC/USDT',
#  'timestamp': 1673491492922,
#  'datetime': '2023-01-12T02:44:52.922Z',
#  'high': 18285.71,
#  'low': 17318.95,
#  'bid': 18263.33,
#  'bidVolume': 0.016016,
#  'ask': 18268.21,
#  'askVolume': 0.005474,
#  'vwap': 17784.86869522,
#  'open': 17424.33,
#  'close': 18266.42,
#  'last': 18266.42,
#  'previousClose': 17424.33,
#  'change': 842.09,
#  'percentage': 4.833,
#  'average': 17845.375,
#  'baseVolume': 2452.021082,
#  'quoteVolume': 43608872.98127579,
#  'info': {'symbol': 'BTCUSDT',
#   'priceChange': '842.09000000',
#   'priceChangePercent': '4.833',
#   'weightedAvgPrice': '17784.86869522',
#   'prevClosePrice': '17424.33000000',
#   'lastPrice': '18266.42000000',
#   'lastQty': '0.06086100',
#   'bidPrice': '18263.33000000',
#   'bidQty': '0.01601600',
#   'askPrice': '18268.21000000',
#   'askQty': '0.00547400',
#   'openPrice': '17424.33000000',
#   'highPrice': '18285.71000000',
#   'lowPrice': '17318.95000000',
#   'volume': '2452.02108200',
# ...

# %%
binancecoinm = ccxt.binancecoinm()
binancecoinm
# Out:
# ccxt.binancecoinm()

# %%
# Not available in US
# binancecoinm.fetchTicker(symbol='BTC/USD')

# %%
coinbasepro = ccxt.coinbasepro()
coinbasepro
# Out:
# ccxt.coinbasepro()

# %%
coinbasepro.fetch_ticker(symbol='BTC/USD')
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1673491493624,
#  'datetime': '2023-01-12T02:44:53.624Z',
#  'high': None,
#  'low': None,
#  'bid': 18264.75,
#  'bidVolume': None,
#  'ask': 18266.99,
#  'askVolume': None,
#  'vwap': None,
#  'open': None,
#  'close': 18265.59,
#  'last': 18265.59,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 33035.56151834,
#  'quoteVolume': None,
#  'info': {'ask': '18266.99',
#   'bid': '18264.75',
#   'volume': '33035.56151834',
#   'trade_id': '481882138',
#   'price': '18265.59',
#   'size': '0.37628564',
#   'time': '2023-01-12T02:44:53.624550Z'}}

# %%
coinbase = ccxt.coinbase()
coinbase
# Out:
# ccxt.coinbase()

# %%
coinbase.fetch_ticker('BTC/USD')
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1673491498037,
#  'datetime': '2023-01-12T02:44:58.037Z',
#  'bid': 18172.12,
#  'ask': 18356.6,
#  'last': 18267.7,
#  'high': None,
#  'low': None,
#  'bidVolume': None,
#  'askVolume': None,
#  'vwap': None,
#  'open': None,
#  'close': 18267.7,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': None,
#  'quoteVolume': None,
#  'info': [{'data': {'base': 'BTC', 'currency': 'USD', 'amount': '18267.7'}},
#   {'data': {'base': 'BTC', 'currency': 'USD', 'amount': '18356.60'}},
#   {'data': {'base': 'BTC', 'currency': 'USD', 'amount': '18172.12'}}]}

# %%
binance.name
# Out:
# 'Binance US'

# %%
binance.has
# Out:
# {'publicAPI': True,
#  'privateAPI': True,
#  'CORS': None,
#  'spot': True,
#  'margin': True,
#  'swap': True,
#  'future': True,
#  'option': None,
#  'addMargin': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': None,
#  'createDepositAddress': False,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'createPostOnlyOrder': None,
#  'createReduceOnlyOrder': True,
#  'createStopOrder': True,
#  'createStopLimitOrder': True,
#  'createStopMarketOrder': False,
#  'editOrder': True,
#  'fetchAccounts': None,
#  'fetchBalance': True,
#  'fetchBidsAsks': True,
#  'fetchBorrowInterest': True,
#  'fetchBorrowRate': True,
#  'fetchBorrowRateHistory': True,
#  'fetchBorrowRatesPerSymbol': False,
#  'fetchBorrowRates': False,
#  'fetchCanceledOrders': False,
#  'fetchClosedOrder': False,
#  'fetchClosedOrders': 'emulated',
#  'fetchCurrencies': True,
#  'fetchDeposit': False,
#  'fetchDepositAddress': True,
# ...

# %%
coinbase.name
# Out:
# 'Coinbase'

# %%
coinbase.has
# Out:
# {'publicAPI': True,
#  'privateAPI': True,
#  'CORS': True,
#  'spot': True,
#  'margin': False,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'addMargin': False,
#  'cancelAllOrders': None,
#  'cancelOrder': None,
#  'cancelOrders': None,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': None,
#  'createPostOnlyOrder': None,
#  'createReduceOnlyOrder': False,
#  'createStopOrder': False,
#  'createStopLimitOrder': False,
#  'createStopMarketOrder': False,
#  'editOrder': 'emulated',
#  'fetchAccounts': True,
#  'fetchBalance': True,
#  'fetchBidsAsks': None,
#  'fetchBorrowInterest': None,
#  'fetchBorrowRate': False,
#  'fetchBorrowRateHistory': False,
#  'fetchBorrowRatesPerSymbol': False,
#  'fetchBorrowRates': False,
#  'fetchCanceledOrders': None,
#  'fetchClosedOrder': None,
#  'fetchClosedOrders': None,
#  'fetchCurrencies': True,
#  'fetchDeposit': None,
#  'fetchDepositAddress': None,
# ...

# %%
coinbasepro.name
# Out:
# 'Coinbase Pro'

# %%
coinbasepro.has
# Out:
# {'publicAPI': True,
#  'privateAPI': True,
#  'CORS': True,
#  'spot': True,
#  'margin': False,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'addMargin': None,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': None,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'createPostOnlyOrder': None,
#  'createReduceOnlyOrder': None,
#  'createStopOrder': True,
#  'createStopLimitOrder': True,
#  'createStopMarketOrder': True,
#  'editOrder': 'emulated',
#  'fetchAccounts': True,
#  'fetchBalance': True,
#  'fetchBidsAsks': None,
#  'fetchBorrowInterest': None,
#  'fetchBorrowRate': None,
#  'fetchBorrowRateHistory': None,
#  'fetchBorrowRatesPerSymbol': None,
#  'fetchBorrowRates': None,
#  'fetchCanceledOrders': None,
#  'fetchClosedOrder': None,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDeposit': None,
#  'fetchDepositAddress': None,
# ...

# %%
binance.timeframes
# Out:
# {'1s': '1s',
#  '1m': '1m',
#  '3m': '3m',
#  '5m': '5m',
#  '15m': '15m',
#  '30m': '30m',
#  '1h': '1h',
#  '2h': '2h',
#  '4h': '4h',
#  '6h': '6h',
#  '8h': '8h',
#  '12h': '12h',
#  '1d': '1d',
#  '3d': '3d',
#  '1w': '1w',
#  '1M': '1M'}

# %%
binance.load_markets()
# Out:
# {'BTC/USD': {'id': 'BTCUSD',
#   'symbol': 'BTC/USD',
#   'base': 'BTC',
#   'quote': 'USD',
#   'baseId': 'BTC',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': False,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 6, 'price': 2, 'base': 8, 'quote': 4},
#   'limits': {'amount': {'min': 1e-06, 'max': 9000.0},
#    'price': {'min': 0.01, 'max': 100000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'leverage': {'min': None, 'max': None},
#    'market': {'min': 0.0, 'max': 60.25597724}},
#   'info': {'symbol': 'BTCUSD',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'USD',
#    'quotePrecision': '4',
# ...

# %%
binance.load_markets()['BTC/USD']
# Out:
# {'id': 'BTCUSD',
#  'symbol': 'BTC/USD',
#  'base': 'BTC',
#  'quote': 'USD',
#  'baseId': 'BTC',
#  'quoteId': 'USD',
#  'active': True,
#  'type': 'spot',
#  'linear': None,
#  'inverse': None,
#  'spot': True,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'margin': False,
#  'contract': False,
#  'contractSize': None,
#  'expiry': None,
#  'expiryDatetime': None,
#  'optionType': None,
#  'strike': None,
#  'settle': None,
#  'settleId': None,
#  'precision': {'amount': 6, 'price': 2, 'base': 8, 'quote': 4},
#  'limits': {'amount': {'min': 1e-06, 'max': 9000.0},
#   'price': {'min': 0.01, 'max': 100000.0},
#   'cost': {'min': 10.0, 'max': None},
#   'leverage': {'min': None, 'max': None},
#   'market': {'min': 0.0, 'max': 60.25597724}},
#  'info': {'symbol': 'BTCUSD',
#   'status': 'TRADING',
#   'baseAsset': 'BTC',
#   'baseAssetPrecision': '8',
#   'quoteAsset': 'USD',
#   'quotePrecision': '4',
#   'quoteAssetPrecision': '4',
#   'baseCommissionPrecision': '8',
# ...

# %%
pd.DataFrame(binance.load_markets()).T
# Out:
#                  id     symbol  base quote baseId quoteId active  type linear  \
# BTC/USD      BTCUSD    BTC/USD   BTC   USD    BTC     USD   True  spot   None
# ETH/USD      ETHUSD    ETH/USD   ETH   USD    ETH     USD   True  spot   None
# XRP/USD      XRPUSD    XRP/USD   XRP   USD    XRP     USD  False  spot   None
# BCH/USD      BCHUSD    BCH/USD   BCH   USD    BCH     USD   True  spot   None
# LTC/USD      LTCUSD    LTC/USD   LTC   USD    LTC     USD   True  spot   None
# ...             ...        ...   ...   ...    ...     ...    ...   ...    ...
# JAM/USD      JAMUSD    JAM/USD   JAM   USD    JAM     USD   True  spot   None
# PROM/USDT  PROMUSDT  PROM/USDT  PROM  USDT   PROM    USDT   True  spot   None
# PROM/USD    PROMUSD   PROM/USD  PROM   USD   PROM     USD   True  spot   None
# DIA/USDT    DIAUSDT   DIA/USDT   DIA  USDT    DIA    USDT   True  spot   None
# DIA/USD      DIAUSD    DIA/USD   DIA   USD    DIA     USD   True  spot   None
#
# ...

# %%
binance.symbols
# Out:
# ['1INCH/USD',
#  '1INCH/USDT',
#  'AAVE/USD',
#  'AAVE/USDT',
#  'ACH/USD',
#  'ACH/USDT',
#  'ADA/BTC',
#  'ADA/BUSD',
#  'ADA/USD',
#  'ADA/USDC',
#  'ADA/USDT',
#  'ALGO/BUSD',
#  'ALGO/USD',
#  'ALGO/USDT',
#  'ALICE/USD',
#  'ALICE/USDT',
#  'ALPINE/USD',
#  'ALPINE/USDT',
#  'AMP/USD',
#  'ANKR/USD',
#  'ANT/USD',
#  'ANT/USDT',
#  'APE/USD',
#  'APE/USDT',
#  'API3/USD',
#  'API3/USDT',
#  'APT/USD',
#  'APT/USDT',
#  'ASTR/USD',
#  'ASTR/USDT',
#  'ATOM/BTC',
#  'ATOM/USD',
#  'ATOM/USDT',
#  'AUDIO/USD',
#  'AUDIO/USDT',
#  'AVAX/BTC',
#  'AVAX/USD',
#  'AVAX/USDT',
#  'AXL/USD',
#  'AXL/USDT',
#  'AXS/USD',
#  'AXS/USDT',
#  'BAL/USD',
#  'BAL/USDT',
#  'BAND/USD',
#  'BAND/USDT',
#  'BAT/USD',
#  'BAT/USDT',
#  'BCH/BTC',
#  'BCH/USD',
#  'BCH/USDT',
#  'BICO/USD',
#  'BICO/USDT',
#  'BNB/BTC',
#  'BNB/BUSD',
#  'BNB/USD',
#  'BNB/USDT',
#  'BNT/USD',
#  'BNT/USDT',
#  'BOND/USD',
#  'BOND/USDT',
#  'BOSON/USD',
#  'BOSON/USDT',
#  'BTC/BUSD',
#  'BTC/USD',
#  'BTC/USDC',
# ...

# %%
len(binance.symbols)
# Out:
# 345

# %%
binance.currencies
# Out:
# {'1INCH': {'id': '1INCH', 'numericId': None, 'code': '1INCH', 'precision': 8},
#  'AAVE': {'id': 'AAVE', 'numericId': None, 'code': 'AAVE', 'precision': 8},
#  'ACH': {'id': 'ACH', 'numericId': None, 'code': 'ACH', 'precision': 8},
#  'ADA': {'id': 'ADA', 'numericId': None, 'code': 'ADA', 'precision': 8},
#  'ALGO': {'id': 'ALGO', 'numericId': None, 'code': 'ALGO', 'precision': 8},
#  'ALICE': {'id': 'ALICE', 'numericId': None, 'code': 'ALICE', 'precision': 8},
#  'ALPINE': {'id': 'ALPINE',
#   'numericId': None,
#   'code': 'ALPINE',
#   'precision': 8},
#  'AMP': {'id': 'AMP', 'numericId': None, 'code': 'AMP', 'precision': 8},
#  'ANKR': {'id': 'ANKR', 'numericId': None, 'code': 'ANKR', 'precision': 8},
#  'ANT': {'id': 'ANT', 'numericId': None, 'code': 'ANT', 'precision': 8},
#  'APE': {'id': 'APE', 'numericId': None, 'code': 'APE', 'precision': 8},
#  'API3': {'id': 'API3', 'numericId': None, 'code': 'API3', 'precision': 8},
# ...

# %% [markdown]
# ## The Public API
# ### Account/api keys not needed for pulling market data

# %%
binance = ccxt.binanceus()
binance
# Out:
# ccxt.binanceus()

# %%
binance.has
# Out:
# {'publicAPI': True,
#  'privateAPI': True,
#  'CORS': None,
#  'spot': True,
#  'margin': True,
#  'swap': True,
#  'future': True,
#  'option': None,
#  'addMargin': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': None,
#  'createDepositAddress': False,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'createPostOnlyOrder': None,
#  'createReduceOnlyOrder': True,
#  'createStopOrder': True,
#  'createStopLimitOrder': True,
#  'createStopMarketOrder': False,
#  'editOrder': True,
#  'fetchAccounts': None,
#  'fetchBalance': True,
#  'fetchBidsAsks': True,
#  'fetchBorrowInterest': True,
#  'fetchBorrowRate': True,
#  'fetchBorrowRateHistory': True,
#  'fetchBorrowRatesPerSymbol': False,
#  'fetchBorrowRates': False,
#  'fetchCanceledOrders': False,
#  'fetchClosedOrder': False,
#  'fetchClosedOrders': 'emulated',
#  'fetchCurrencies': True,
#  'fetchDeposit': False,
#  'fetchDepositAddress': True,
# ...

# %%
binance.fetch_ticker('BTC/USD')
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1673491499040,
#  'datetime': '2023-01-12T02:44:59.040Z',
#  'high': 18286.07,
#  'low': 17312.68,
#  'bid': 18257.01,
#  'bidVolume': 0.008,
#  'ask': 18259.82,
#  'askVolume': 0.428418,
#  'vwap': 17714.023,
#  'open': 17415.18,
#  'close': 18257.01,
#  'last': 18257.01,
#  'previousClose': 17415.62,
#  'change': 841.83,
#  'percentage': 4.834,
#  'average': 17836.095,
#  'baseVolume': 10512.544416,
#  'quoteVolume': 186219453.9537,
#  'info': {'symbol': 'BTCUSD',
#   'priceChange': '841.8300',
#   'priceChangePercent': '4.834',
#   'weightedAvgPrice': '17714.0230',
#   'prevClosePrice': '17415.6200',
#   'lastPrice': '18257.0100',
#   'lastQty': '0.00200000',
#   'bidPrice': '18257.0100',
#   'bidQty': '0.00800000',
#   'askPrice': '18259.8200',
#   'askQty': '0.42841800',
#   'openPrice': '17415.1800',
#   'highPrice': '18286.0700',
#   'lowPrice': '17312.6800',
#   'volume': '10512.54441600',
#   'quoteVolume': '186219453.9537',
# ...

# %%
binance.fetch_tickers(symbols=['BTC/USDT', 'ETH/USDT'])
# Out:
# {'BTC/USDT': {'symbol': 'BTC/USDT',
#   'timestamp': 1673491500921,
#   'datetime': '2023-01-12T02:45:00.921Z',
#   'high': 18285.71,
#   'low': 17318.95,
#   'bid': 18260.8,
#   'bidVolume': 0.015967,
#   'ask': 18265.38,
#   'askVolume': 0.232002,
#   'vwap': 17784.86869522,
#   'open': 17424.33,
#   'close': 18266.42,
#   'last': 18266.42,
#   'previousClose': 17424.33,
#   'change': 842.09,
#   'percentage': 4.833,
#   'average': 17845.375,
#   'baseVolume': 2452.021082,
#   'quoteVolume': 43608872.98127579,
#   'info': {'symbol': 'BTCUSDT',
#    'priceChange': '842.09000000',
#    'priceChangePercent': '4.833',
#    'weightedAvgPrice': '17784.86869522',
#    'prevClosePrice': '17424.33000000',
#    'lastPrice': '18266.42000000',
#    'lastQty': '0.06086100',
#    'bidPrice': '18260.80000000',
#    'bidQty': '0.01596700',
#    'askPrice': '18265.38000000',
#    'askQty': '0.23200200',
#    'openPrice': '17424.33000000',
#    'highPrice': '18285.71000000',
# ...

# %%
binance.fetch_ohlcv(symbol='BTC/USD', timeframe='1d', limit=1000)
# Out:
# [[1587168000000, 7030.0, 7304.99, 7025.0, 7260.0, 312.751377],
#  [1587254400000, 7261.6, 7272.0, 7062.93, 7130.72, 240.463814],
#  [1587340800000, 7132.79, 7224.99, 6753.54, 6844.17, 587.940489],
#  [1587427200000, 6832.56, 6955.0, 6772.0, 6852.07, 586.357851],
#  [1587513600000, 6850.35, 7168.93, 6826.55, 7139.37, 424.719849],
#  [1587600000000, 7139.36, 7760.0, 7036.54, 7485.17, 772.054922],
#  [1587686400000, 7487.17, 7658.58, 7385.44, 7510.29, 489.288726],
#  [1587772800000, 7512.36, 7732.44, 7440.0, 7546.38, 433.928898],
#  [1587859200000, 7545.72, 7707.02, 7484.42, 7702.31, 390.285977],
#  [1587945600000, 7702.31, 7802.31, 7633.85, 7790.32, 411.177025],
#  [1588032000000, 7792.34, 7792.34, 7676.3, 7760.0, 209.772031],
#  [1588118400000, 7755.01, 8971.94, 7720.0, 8788.63, 1554.017238],
#  [1588204800000, 8790.92, 9465.8, 8415.01, 8628.94, 1698.222295],
#  [1588291200000, 8624.69, 9073.05, 8624.69, 8828.27, 717.823193],
# ...

# %%
# index is bucket of prices from exchanges
# not available in US
# binance.fetchIndexOHLCV(symbol='BTC/USD', timeframe='1d', limit=1000)

# %%
binance.fetchOrderBook(symbol='BTC/USD')
# Out:
# {'symbol': 'BTC/USD',
#  'bids': [[18257.09, 0.376334],
#   [18257.08, 0.05],
#   [18257.07, 0.012496],
#   [18257.06, 0.05],
#   [18257.04, 0.05],
#   [18257.02, 0.05],
#   [18257.01, 0.008],
#   [18256.47, 0.27384],
#   [18256.44, 0.450834],
#   [18256.3, 0.05],
#   [18256.29, 0.05],
#   [18256.28, 0.05],
#   [18256.25, 0.12555],
#   [18256.24, 0.933916],
#   [18255.88, 0.05],
#   [18255.86, 0.612221],
#   [18255.3, 0.569797],
#   [18255.29, 0.300654],
#   [18255.27, 0.614301],
#   [18255.26, 0.01],
#   [18255.02, 0.01],
#   [18254.71, 0.001],
#   [18254.68, 0.004384],
#   [18254.63, 0.012458],
#   [18254.3, 0.004373],
#   [18253.92, 0.01],
#   [18253.91, 0.06069],
#   [18253.56, 0.973696],
#   [18253.06, 0.325],
#   [18253.04, 0.01],
#   [18253.03, 0.01],
#   [18252.95, 0.004418],
#   [18252.36, 0.05908],
#   [18252.3, 1.159721],
#   [18252.0, 0.076853],
#   [18251.22, 0.325],
#   [18251.04, 0.01],
#   [18251.03, 0.001332],
#   [18251.0, 6.451316],
#   [18250.67, 1.312606],
# ...

# %%
binance.fetchTrades(symbol='BTC/USD')
# Out:
# [{'info': {'a': '56942668',
#    'p': '18273.4800',
#    'q': '0.00403800',
#    'f': '61536898',
#    'l': '61536898',
#    'T': '1673491345326',
#    'm': True,
#    'M': True},
#   'timestamp': 1673491345326,
#   'datetime': '2023-01-12T02:42:25.326Z',
#   'symbol': 'BTC/USD',
#   'id': '56942668',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 18273.48,
#   'amount': 0.004038,
#   'cost': 73.78831224,
#   'fee': None,
#   'fees': []},
#  {'info': {'a': '56942669',
#    'p': '18273.2400',
#    'q': '0.00078700',
#    'f': '61536899',
#    'l': '61536899',
#    'T': '1673491345326',
#    'm': True,
#    'M': True},
#   'timestamp': 1673491345326,
#   'datetime': '2023-01-12T02:42:25.326Z',
#   'symbol': 'BTC/USD',
#   'id': '56942669',
#   'order': None,
#   'type': None,
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 18273.24,
#   'amount': 0.000787,
#   'cost': 14.38103988,
#   'fee': None,
#   'fees': []},
# ...

# %% [markdown]
# ## Loading Historical Data

# %%
binance.timeframes
# Out:
# {'1s': '1s',
#  '1m': '1m',
#  '3m': '3m',
#  '5m': '5m',
#  '15m': '15m',
#  '30m': '30m',
#  '1h': '1h',
#  '2h': '2h',
#  '4h': '4h',
#  '6h': '6h',
#  '8h': '8h',
#  '12h': '12h',
#  '1d': '1d',
#  '3d': '3d',
#  '1w': '1w',
#  '1M': '1M'}

# %%
data = binance.fetch_ohlcv(symbol='BTC/USD', timeframe='1d', limit=1000)
data
# Out:
# [[1587168000000, 7030.0, 7304.99, 7025.0, 7260.0, 312.751377],
#  [1587254400000, 7261.6, 7272.0, 7062.93, 7130.72, 240.463814],
#  [1587340800000, 7132.79, 7224.99, 6753.54, 6844.17, 587.940489],
#  [1587427200000, 6832.56, 6955.0, 6772.0, 6852.07, 586.357851],
#  [1587513600000, 6850.35, 7168.93, 6826.55, 7139.37, 424.719849],
#  [1587600000000, 7139.36, 7760.0, 7036.54, 7485.17, 772.054922],
#  [1587686400000, 7487.17, 7658.58, 7385.44, 7510.29, 489.288726],
#  [1587772800000, 7512.36, 7732.44, 7440.0, 7546.38, 433.928898],
#  [1587859200000, 7545.72, 7707.02, 7484.42, 7702.31, 390.285977],
#  [1587945600000, 7702.31, 7802.31, 7633.85, 7790.32, 411.177025],
#  [1588032000000, 7792.34, 7792.34, 7676.3, 7760.0, 209.772031],
#  [1588118400000, 7755.01, 8971.94, 7720.0, 8788.63, 1554.017238],
#  [1588204800000, 8790.92, 9465.8, 8415.01, 8628.94, 1698.222295],
#  [1588291200000, 8624.69, 9073.05, 8624.69, 8828.27, 717.823193],
# ...

# %%
len(data)
# Out:
# 1000

# %% [markdown]
# ### Working with the since parameter

# %%
start = '2020-05-15 00:00:00Z'

# %%
unix = binance.parse8601(start)
unix
# Out:
# 1589500800000

# %%
# since, but max is 1000 bars
data = binance.fetch_ohlcv(symbol='BTC/USD', since=unix, limit=1000, timeframe='1d')
data
# Out:
# [[1589500800000, 9796.99, 9841.87, 9106.48, 9310.0, 1257.169096],
#  [1589587200000, 9308.68, 9582.35, 9218.68, 9386.31, 507.016404],
#  [1589673600000, 9385.92, 9889.88, 9330.18, 9676.35, 706.264631],
#  [1589760000000, 9692.89, 9949.33, 9450.0, 9725.84, 929.217198],
#  [1589846400000, 9726.84, 9890.0, 9466.29, 9783.0, 645.957455],
#  [1589932800000, 9780.25, 9832.0, 9275.82, 9512.39, 700.740544],
#  [1590019200000, 9506.63, 9561.15, 8800.0, 9055.57, 874.97111],
#  [1590105600000, 9054.75, 9259.08, 8934.0, 9166.06, 556.309475],
#  [1590192000000, 9166.06, 9312.7, 9087.11, 9183.4, 264.651102],
#  [1590278400000, 9183.4, 9297.57, 8688.0, 8706.69, 507.398787],
#  [1590364800000, 8711.44, 9011.04, 8634.85, 8902.35, 636.46142],
#  [1590451200000, 8890.65, 9005.64, 8700.0, 8841.2, 314.451593],
#  [1590537600000, 8848.06, 9225.1, 8811.23, 9203.0, 372.456111],
#  [1590624000000, 9205.0, 9625.0, 9118.9, 9580.0, 632.123925],
#  [1590710400000, 9580.0, 9607.6, 9332.25, 9420.89, 410.957353],
# ...

# %%
len(data)
# Out:
# 973

# %%
# converting back
binance.iso8601(unix)
# Out:
# '2020-05-15T00:00:00.000Z'

# %%
def get_history(symbol, interval, start=None, limit=1000):
    if start:
        start = binance.parse8601(start)

    data = binance.fetch_ohlcv(symbol=symbol, timeframe=interval, since=start, limit=limit)

    df = pd.DataFrame(data)
    df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
    df.Date = pd.to_datetime(df.Date, unit='ms')
    df.set_index('Date', inplace=True)

    return df

# %%
df = get_history(symbol='BTC/USD', interval='1h', limit=1000)
df
# Out:
#                          Open      High       Low     Close       Volume
# Date
# 2022-12-01 11:00:00  17094.61  17106.70  17043.97  17102.98   159.123741
# 2022-12-01 12:00:00  17105.54  17156.02  17099.86  17136.53   258.155362
# 2022-12-01 13:00:00  17136.02  17312.76  16979.94  17090.91   931.311015
# 2022-12-01 14:00:00  17085.70  17148.02  17027.32  17110.83   369.285166
# 2022-12-01 15:00:00  17112.57  17142.18  16886.68  16979.00   775.102169
# ...                       ...       ...       ...       ...          ...
# 2023-01-11 22:00:00  17552.21  17586.46  17508.55  17551.30   320.440934
# 2023-01-11 23:00:00  17551.92  17988.76  17545.40  17934.99  1617.574793
# 2023-01-12 00:00:00  17936.52  18286.07  17899.97  18243.38  1295.562355
# 2023-01-12 01:00:00  18238.23  18274.85  18134.62  18220.35  1429.391065
# 2023-01-12 02:00:00  18217.92  18276.51  18205.54  18259.25   599.179123
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2022-12-01 11:00:00 to 2023-01-12 02:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1000 non-null   float64
#  1   High    1000 non-null   float64
#  2   Low     1000 non-null   float64
#  3   Close   1000 non-null   float64
#  4   Volume  1000 non-null   float64
# dtypes: float64(5)
# memory usage: 46.9 KB

# %%
start = '2021-11-15 09:00:00'

# %%
df = get_history(symbol='BTC/USD', interval='1h', start=start, limit=1000)
df
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2021-11-15 09:00:00  65760.61  66355.15  65695.41  66005.80  30.696644
# 2021-11-15 10:00:00  66005.85  66072.64  65771.02  65955.75  16.368932
# 2021-11-15 11:00:00  65970.53  65970.53  65648.86  65735.81  10.431369
# 2021-11-15 12:00:00  65750.95  65963.67  65564.12  65700.91  18.346965
# 2021-11-15 13:00:00  65694.25  65785.10  65387.73  65501.50  18.501665
# ...                       ...       ...       ...       ...        ...
# 2021-12-26 20:00:00  50382.22  50413.87  50300.92  50308.58   8.599640
# 2021-12-26 21:00:00  50304.30  51062.50  49954.78  50824.24  75.882572
# 2021-12-26 22:00:00  50825.71  51308.75  50814.75  51007.46  35.652106
# 2021-12-26 23:00:00  51005.73  51071.03  50666.66  50792.37  39.785142
# 2021-12-27 00:00:00  50792.37  51003.54  50594.75  50629.39  66.223669
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Loading Historical Data in Batches

# %%
import time

# %%
def get_history(symbol, interval, start=None, limit=1000):
    if start:
        start = binance.parse8601(start)

    data = binance.fetch_ohlcv(symbol=symbol, timeframe=interval, since=start, limit=limit)
    # timestamp of last bar
    last_bar_actual = data[-1][0]

    # timestamp of current bar
    # using 2 for limit makes code more stable
    last_bar_target = binance.fetch_ohlcv(symbol=symbol, timeframe=interval, limit=2)[-1][0]

    while last_bar_target != last_bar_actual:

        time.sleep(0.1)
        data_add = binance.fetch_ohlcv(symbol=symbol, timeframe=interval, since=last_bar_actual, limit=limit)
        data += data_add[1:]
        last_bar_actual = data[-1][0]
        last_bar_target = binance.fetch_ohlcv(symbol=symbol, timeframe=interval, limit=2)[-1][0]

    df = pd.DataFrame(data)
    df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
    df.Date = pd.to_datetime(df.Date, unit='ms')
    df.set_index('Date', inplace=True)

    return df

# %%
start = '2020-11-15 09:00:00'
df = get_history(symbol='BTC/USD', interval='1h', start=start, limit=1000)
df
# Out:
#                          Open      High       Low     Close       Volume
# Date
# 2020-11-15 09:00:00  16134.86  16134.86  16055.81  16080.38     5.781735
# 2020-11-15 10:00:00  16083.43  16100.55  15979.13  16008.79     5.509548
# 2020-11-15 11:00:00  15996.00  16100.00  15954.11  15975.52     4.401407
# 2020-11-15 12:00:00  15965.85  16081.99  15950.00  15995.04     5.678717
# 2020-11-15 13:00:00  15999.23  16093.71  15970.56  16063.75     5.172437
# ...                       ...       ...       ...       ...          ...
# 2023-01-11 22:00:00  17552.21  17586.46  17508.55  17551.30   320.440934
# 2023-01-11 23:00:00  17551.92  17988.76  17545.40  17934.99  1617.574793
# 2023-01-12 00:00:00  17936.52  18286.07  17899.97  18243.38  1295.562355
# 2023-01-12 01:00:00  18238.23  18274.85  18134.62  18220.35  1429.391065
# 2023-01-12 02:00:00  18217.92  18276.51  18205.54  18273.93   628.359585
#
# [18896 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18896 entries, 2020-11-15 09:00:00 to 2023-01-12 02:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    18896 non-null  float64
#  1   High    18896 non-null  float64
#  2   Low     18896 non-null  float64
#  3   Close   18896 non-null  float64
#  4   Volume  18896 non-null  float64
# dtypes: float64(5)
# memory usage: 885.8 KB

# %%
df.index.is_unique
# Out:
# True
